# %% [markdown]
# ![image.png](attachment:image.png)

# %%
age1 = 18
年齡3 = 12
print(age1)
print(年齡3)
# Out:
# 18
# 12

# %%
salary =  25000
commission = 1000
sales = 18
pay = salary + commission * sales
print("銷售量:",sales)
print("薪資:",pay,"元")
# Out:
# 銷售量: 18
# 薪資: 43000 元

# %%
price = 250
print(price)
price = 199
print(price)
price = 150.99
print(price)
_x5 = 20
del price
print(price)
# Out:
# 250
# 199
# 150.99
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 9>()
#       7 _x5 = 20
#       8 del price
# ----> 9 print(price)
#
# NameError: name 'price' is not defined

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
c1 = 20
c2 = 10
ctotal = c1 * 5 + c2 * 3
print("CTotal:",ctotal)

ctotal = c1 * (2 + c2) * 7
print("CTotal2:",ctotal)
# Out:
# CTotal: 130
# CTotal2: 1680

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
count = 0
count = count + 1
count = count + 1
print("count:",count)

i = 0
i = i + 2
print("i:",i)
i += 3;
print("i:",i)
# Out:
# count: 2
# i: 2
# i: 5

# %%
num = 10
num += 9
print(num)
num -= 8
print(num)
num *= 7
print(num)
num //= 6
print(num)
num %= 5
print(num)
num /= 4
print(num)
num **= 3
print(num)
# Out:
# 19
# 11
# 77
# 12
# 2
# 0.5
# 0.125

# %%
x = 10
x /= 10
print(x)

x = 9 + 3 *2 ** 2 -1
print(x)
# Out:
# 1.0
# 20

# %% [markdown]
# ## 作業

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(2 + 3)
print('2'+'3')
#print(2 + '3')
print(str(2) + '3')
print(2 + int('3'))
# Out:
# 5
# 23
# 23
# 5

# %%
a = 3
b = 4

tmp = a
a = b
b = tmp

print(a,b)
# Out:
# 4 3
