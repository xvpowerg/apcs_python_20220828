# %%
tc1,tc2,tc3 = 0,25,98
ft1 = 9 / 5 * tc1 + 32
ft2 = 9 / 5 * tc2 + 32
ft3 = 9 / 5 * tc3 + 32

print("攝氏:",tc1,"華氏:",ft1)
print("攝氏:",tc2,"華氏:",ft2)
print("攝氏:",tc3,"華氏:",ft3)
# Out:
# 攝氏: 0 華氏: 32.0
# 攝氏: 25 華氏: 77.0
# 攝氏: 98 華氏: 208.4

# %%
a1 = 20
b2 = 40

a1,b2 = b2,a1
print(a1,b2)
# Out:
# 40 20

# %%
#tc = int(input("請輸入攝氏溫度:"))
tc = input("請輸入攝氏溫度:")
tc = int(tc)
tf = 9 / 5 * tc + 32
print("攝氏:",tc ,"華氏:",tf)
# Out:
# 請輸入攝氏溫度:32
# 攝氏: 32 華氏: 89.6

# %%
height = float(input("身高公分:"))
weight = int(input("體重公斤:"))
bmi = weight / ((height/100) ** 2)
print("bmi:",bmi)
# Out:
# 身高公分:180
# 體重公斤:73
# bmi: 22.530864197530864

# %% [markdown]
# ## 作業
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
var1 = 123
print(type(var1))
var2 = 3.14
print(type(var2))
var3 = True
print(type(var3))
var3 = 1.556
print(type(var3))
var4 = 'Hello'
print(type(var4))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'float'>
# <class 'str'>

# %%
x = 123
print(id(x))
x = 12
print(id(x))
y = x
print(id(y))
g = 12
print(id(g))
# Out:
# 140711461596736
# 140711461593184
# 140711461593184
# 140711461593184

# %%
x = 10
print(x)
print(type(x))
x = x + 5.5
print(x)
print(type(x))
# Out:
# 10
# <class 'int'>
# 15.5
# <class 'float'>

# %%
x = 10.5
print(x)
print(type(x))
y = int(x) + 5
print(y)
print(type(y))
z = float(y) + 5
print(z)
print(type(z))
# Out:
# 10.5
# <class 'float'>
# 15
# <class 'int'>
# 20.0
# <class 'float'>

# %%
x,y = 5,0
print(x,bool(x))
print(y,bool(y))
x,y=-2,0
print(x,bool(x))
print(y,bool(y))
x,y = 1.5,0.0
print(x,bool(x))
print(y,bool(y))

x = "Hi"
y = ""
print(x,bool(x))
print(y,bool(y))

x = [1,2,3]
y = []
print(x,bool(x))
print(y,bool(y))
# Out:
# 5 True
# 0 False
# -2 True
# 0 False
# 1.5 True
# 0.0 False
# Hi True
#  False
# [1, 2, 3] True
# [] False

# %%
html = '<input type="text" name="acc" placeholder="帳號"/>'
print(html)

str1 = "This is David's phone"
print(str1)
str2 = 'This is David\'s phone'
print(str2)

div1 ='''<div class="div_class">
        <input type="checkbox" name="c1" value="1"> 唱歌    
        <input type="checkbox" name="c1" value="2"> 跳舞    
        <input type="checkbox" name="c1" value="3"> 動漫      
     </div>
     '''
print(div1)

path1 =  r"c:\nno\script"
print(path1)
# Out:
# <input type="text" name="acc" placeholder="帳號"/>
# This is David's phone
# This is David's phone
# <div class="div_class">
#         <input type="checkbox" name="c1" value="1"> 唱歌
#         <input type="checkbox" name="c1" value="2"> 跳舞
#         <input type="checkbox" name="c1" value="3"> 動漫
#      </div>
#
# c:\nno\script

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
mystring =  "Hello World"
print(mystring)
print(mystring[2])
print(mystring[-3])
print(mystring[2:])
print(mystring[:3])
print(mystring[1:4])
print(mystring[-4:-1])
print(mystring[::-1])
# Out:
# Hello World
# l
# r
# llo World
# Hel
# ell
# orl
# dlroW olleH

# %% [markdown]
# ## 作業 檢查使用者輸入的字串是否為迴文

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
pid = input("請輸入身分證字號:")
v1 = int(pid[1])
if v1 == 1:
    print("先生")
else:
    print("小姐")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list1 = ["H","i"]
tuple1 = ("H","i")
print(tuple1)
print(list1)

list1[1] = 'a'
#tuple1[0] = 'k'
print(list1)
# Out:
# ('H', 'i')
# ['H', 'i']
# ['H', 'a']

# %%
list1 = ['H','e','l','l','o', 'W','o','r','l','d']
print(list1[0])
print(list1[1])
print(list1[-1])
print(list1[-3])

print(list1[2:])
print(list1[:-3])
print(list1[3:5])

print(list1[::2])
# Out:
# H
# e
# d
# r
# ['l', 'l', 'o', 'W', 'o', 'r', 'l', 'd']
# ['H', 'e', 'l', 'l', 'o', 'W', 'o']
# ['l', 'o']
# ['H', 'l', 'o', 'o', 'l']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
scores = [60,70,75,90,100]
print(scores)
scores[2] = 80
print(scores)
del scores[2]
print(scores)
del scores[1:3]
print(scores)
del scores
print(scores)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
set1 = {1,2,2,3,1}
print(set1)
print(2 in set1)
print(5 in set1)
for x in set1:
    print(x)
    
myList = [5,6,7,8,6]
print(myList)
print(7 in myList)
for y in myList:
    print(y)
# Out:
# {1, 2, 3}
# True
# False
# 1
# 2
# 3
# [5, 6, 7, 8, 6]
# True
# 5
# 6
# 7
# 8
# 6

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
scores ={'Ch':95,'En':80,'Ma':70,'Ch':100}
print(scores)
scores['Ma'] = 75
print(scores)
scores['Sc'] = 89
print(scores)
print(scores['En'])
print(scores['OS'])
# Out:
# {'Ch': 100, 'En': 80, 'Ma': 70}
# {'Ch': 100, 'En': 80, 'Ma': 75}
# {'Ch': 100, 'En': 80, 'Ma': 75, 'Sc': 89}
# 80
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [18], in <cell line: 8>()
#       6 print(scores)
#       7 print(scores['En'])
# ----> 8 print(scores['OS'])
#
# KeyError: 'OS'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
places = {'A':'臺北市', 'B':'臺中市', 'C':'基隆市', 'D':'臺南市', 'E':'高雄市', 'F':'新北市',
          'G':'宜蘭縣', 'H':'桃園市', 'I':'嘉義市', 'J':'新竹縣', 'K':'苗栗縣',
          'M':'南投縣', 'N':'彰化縣', 'O':'新竹市', 'P':'雲林縣', 'Q':'嘉義縣', 'T':'屏東縣',
          'U':'花蓮縣', 'V':'臺東縣', 'W':'金門縣', 'X':'澎湖縣', 'Z':'連江縣',
          'L':'臺中縣', 'R':'臺南縣', 'S':'高雄縣', 'Y':'陽明山'}
pid = input("身分證字號:")

brith = pid[0]
print("出生地:",places[brith])
# Out:
# 身分證字號:A123456789
# 出生地: 臺北市

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
prizes = ('汽車一輛','獎金十萬','家庭劇院一組',
          '筆記型電腦一台','iPhone 手機一支',
          'Switch遊樂器一台',
          '飯店住宿券一張','飯店住宿券一張',
          '下午茶券兩張','下午茶券兩張')
no = int(input("摸彩號碼:")) - 1
if no < len(prizes):
   print("抽中:",prizes[no])
else:
   print("銘謝惠顧")
# Out:
# 摸彩號碼:1
# 抽中: 汽車一輛

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
carList = ['Audi', 'Toyota', 'Benz', 'BMW', 'Mazda', 'Ford', 'BMW', 'Benz', 'BMW', 'Mazda']
carSet  = {'Audi', 'Toyota', 'Benz', 'BMW', 'Mazda', 'Ford', 'BMW', 'Benz', 'BMW', 'Mazda'}


print("車輛清單:",carList)
print("第三台車:",carList[3-1])
print(f"共有{len(carSet)}品牌")

LuxuryCar  = {"Audi", "Benz", "BMW"}
LuxuryDict = {"Audi":0, "Benz":0, "BMW":0}

for car in carList:
    if car in LuxuryCar:
        LuxuryDict[car] += 1
        
print("豪車品牌:",LuxuryDict)
# Out:
# 車輛清單: ['Audi', 'Toyota', 'Benz', 'BMW', 'Mazda', 'Ford', 'BMW', 'Benz', 'BMW', 'Mazda']
# 第三台車: Benz
# 共有6品牌
# 豪車品牌: {'Audi': 1, 'Benz': 2, 'BMW': 3}

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
#a = 3
#b = 5
#a = True
#b = False
a = True
b = 0
print(a == b)
print(a != b)
print(a > b)
print(a >= b)
print(a < b)
print(a <= b)
# Out:
# False
# True
# True
# True
# False
# False

# %%
#a = 3
#b = 5
#a = True
#b = False
a = True
b = 0
print(a == b)
print(a != b)
print(a > b)
print(a >= b)
print(a < b)
print(a <= b)
# Out:
# False
# True
# True
# True
# False
# False

# %%
a = 'Hello'
b = 'World'
print(a==b)
print(a!=b)
print(a>b)
print(a>=b)
print(a<b)
print(a<=b)
# Out:
# False
# True
# False
# False
# True
# True

# %%
a = 'Hello'
print('H' in a)
print('h' in a)
print('H' not in a)
print('h' not in a)
# Out:
# True
# False
# False
# True

# %%
a = 'Hello'
b = 'World'
print(b is a)
print(b is not a)
print(id(a))
print(id(b))
b = 'Hello'
print(b is a)
print(b is not a)
print(id(a))
print(id(b))
# Out:
# False
# True
# 2059909866480
# 2059926552304
# True
# False
# 2059909866480
# 2059909866480

# %% [markdown]
#  ## 邏輯運算符號
#  ![image.png](attachment:image.png)

# %%
h1, h2, h3, h4 = 175, 178, 183, 190
print(h1>=180 and h1<=185)
print(h2>=180 and h2<=185)
print(h3>=180 and h3<=185)
print(h4>=180 and h4<=185)
print(180 <= h4 <=185)
print("==============")
w1, w2, w3, w4 = 95, 85, 75, 65
print(70<w1<90)
print(90>w2>70)
print(70<w3>90)  #(w3>90)
print(70>w4<90)  #(w4<70)
# Out:
# False
# False
# True
# False
# False
# ...
# False
# True
# False
# True

# %%
ch1, ch2, ch3, ch4 = 75, 60, 55, 40
en1, en2, en3, en4 = 60, 58, 70, 50
print(ch1>=60 or en1>=60)
print(ch2>=60 or en2>=60)
print(ch3>=60 or en3>=60)
print(ch4>=60 or en4>=60)
# Out:
# True
# True
# True
# False

# %%
h1,h2,h3,h4 = 175,178,183,190
w1,w2,w3,w4 = 95,85,75,65
print(not h2 < 180)
print(not h3 < 180)
print(not (h1 > 180 and w1 < 80))
print(not (h2 > 180 or  not w2 < 80))
print(not (h3 > 180 or w3 < 80))
print(not h4 > 180 and not w4 < 80)
# Out:
# False
# True
# True
# False
# False
# False
